# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('alzheimerpt3.txt', sep='\t', lineterminator='\n')

# %%
df.tail(92)
# Out:
#                                                   Notes      State  \
# 2893                                                NaN  Wisconsin
# 2894                                              ---\r        NaN
# 2895    Dataset: Underlying Cause of Death, 1999-2020\r        NaN
# 2896                                Query Parameters:\r        NaN
# 2897           2013 Urbanization: Large Central Metro\r        NaN
# ...                                                 ...        ...
# 2980  2019 data. Underlying and multiple cause of de...        NaN
# 2981  unspecified firearm discharge, ICD-10 code X95...        NaN
# 2982                                            2020.\r        NaN
# 2983  14. Changes to cause of death classification a...        NaN
# 2984  http://wonder.cdc.gov/wonder/help/ucd.html#ICD...        NaN
#
#       State Code Gender Gender Code   Race Race Code    Year  Year Code  \
# 2893        55.0   Male           M  White    2106-3  2020.0     2020.0
# ...

# %%
df.head(25)
# Out:
#    Notes    State  State Code  Gender Gender Code                       Race  \
# 0    NaN  Alabama         1.0  Female           F  Black or African American
# 1    NaN  Alabama         1.0  Female           F  Black or African American
# 2    NaN  Alabama         1.0  Female           F  Black or African American
# 3    NaN  Alabama         1.0  Female           F  Black or African American
# 4    NaN  Alabama         1.0  Female           F  Black or African American
# 5    NaN  Alabama         1.0  Female           F  Black or African American
# 6    NaN  Alabama         1.0  Female           F  Black or African American
# 7    NaN  Alabama         1.0  Female           F  Black or African American
# 8    NaN  Alabama         1.0  Female           F  Black or African American
# 9    NaN  Alabama         1.0  Female           F  Black or African American
# 10   NaN  Alabama         1.0  Female           F  Black or African American
# ...

# %%
df.drop(['Notes'], axis=1)
# Out:
#         State  State Code  Gender Gender Code                       Race  \
# 0     Alabama         1.0  Female           F  Black or African American
# 1     Alabama         1.0  Female           F  Black or African American
# 2     Alabama         1.0  Female           F  Black or African American
# 3     Alabama         1.0  Female           F  Black or African American
# 4     Alabama         1.0  Female           F  Black or African American
# ...       ...         ...     ...         ...                        ...
# 2980      NaN         NaN     NaN         NaN                        NaN
# 2981      NaN         NaN     NaN         NaN                        NaN
# 2982      NaN         NaN     NaN         NaN                        NaN
# 2983      NaN         NaN     NaN         NaN                        NaN
# 2984      NaN         NaN     NaN         NaN                        NaN
#
#      Race Code    Year  Year Code                  Cause of death  \
# ...

# %%
n = 91
 
# Removing last n rows
df_dropped = df.iloc[:-n]

# %%
df_dropped.drop(['Notes'], axis=1)
# Out:
#           State  State Code  Gender Gender Code                       Race  \
# 0       Alabama         1.0  Female           F  Black or African American
# 1       Alabama         1.0  Female           F  Black or African American
# 2       Alabama         1.0  Female           F  Black or African American
# 3       Alabama         1.0  Female           F  Black or African American
# 4       Alabama         1.0  Female           F  Black or African American
# ...         ...         ...     ...         ...                        ...
# 2889  Wisconsin        55.0    Male           M                      White
# 2890  Wisconsin        55.0    Male           M                      White
# 2891  Wisconsin        55.0    Male           M                      White
# 2892  Wisconsin        55.0    Male           M                      White
# 2893  Wisconsin        55.0    Male           M                      White
#
#      Race Code    Year  Year Code                  Cause of death  \
# ...

# %%
df_dropped.drop(['Notes'], axis=1)
# Out:
#           State  State Code  Gender Gender Code                       Race  \
# 0       Alabama         1.0  Female           F  Black or African American
# 1       Alabama         1.0  Female           F  Black or African American
# 2       Alabama         1.0  Female           F  Black or African American
# 3       Alabama         1.0  Female           F  Black or African American
# 4       Alabama         1.0  Female           F  Black or African American
# ...         ...         ...     ...         ...                        ...
# 2889  Wisconsin        55.0    Male           M                      White
# 2890  Wisconsin        55.0    Male           M                      White
# 2891  Wisconsin        55.0    Male           M                      White
# 2892  Wisconsin        55.0    Male           M                      White
# 2893  Wisconsin        55.0    Male           M                      White
#
#      Race Code    Year  Year Code                  Cause of death  \
# ...

# %%
df_dropped['Race'].hist(bins = 25,
                            color = 'coral',
                            edgecolor = 'black',
                            figsize = (10,6))

plt.title('Ethnicity', fontsize = 16)
plt.xlabel('Race')
plt.ylabel('Number of Deaths per thousand')
plt.savefig('ethnicity2.pdf');

# %%
df_dropped['Gender'].hist(bins = 25,
                            color = 'coral',
                            edgecolor = 'black',
                            figsize = (10,6))

plt.title('Gender', fontsize = 16)
plt.xlabel('Gender')
plt.ylabel('Number of Deaths per thousand')
plt.savefig('gen2.pdf');
